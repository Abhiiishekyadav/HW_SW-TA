# %% [markdown]
# importing libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model

# %% [markdown]
# dataset generation

# %%
cifar10 = tf.keras.datasets.cifar10

# train and test set splitting
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
#from keras.datasets import mnist
import matplotlib.pyplot as plt

# Load the MNIST dataset
#(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Display the shape of the dataset
print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Testing data shape:", x_test.shape)
print("Testing labels shape:", y_test.shape)

# Plot some sample images
plt.figure(figsize=(10, 5))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')

plt.show()
# Out:
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Testing data shape: (10000, 32, 32, 3)
# Testing labels shape: (10000, 1)

# %%
# Normalization
x_train, x_test = x_train / 255.0, x_test / 255.0

# flattening
y_train, y_test = y_train.flatten(), y_test.flatten()

# %% [markdown]
# visualization

# %%
# plotting images
fig, ax = plt.subplots(5, 5)
k = 0

for i in range(5):
	for j in range(5):
		ax[i][j].imshow(x_train[k], aspect='auto')
		k += 1

plt.show()

# %% [markdown]
# #Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar100

#48,128,88,
#68,182,80,
#112,40,256

# Build the CNN model
model = tf.keras.models.Sequential()

# Layer 1: Convolutional layer with 32 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(48, (3, 3), activation='relu', input_shape=(32, 32, 3)))


# Layer 2: Convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(128, (3, 3), activation='relu'))

# Layer 3: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(88, (3, 3), activation='relu'))

# Layer 4: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(68, (3, 3), activation='relu'))

# Layer 5: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(182, (3, 3), activation='relu'))

# Layer 6: Convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(80, (3, 3), activation='relu'))

# Layer 7: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(112, (3, 3), activation='relu'))

# Layer 8: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(40, (3, 3), activation='relu'))

# Layer 9: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
model.add(layers.Conv2D(256, (3, 3), activation='relu'))

# Layer 10: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
#model.add(layers.Conv2D(842, (3, 3), activation='relu'))

# Layer 11: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
#model.add(layers.Conv2D(861, (3, 3), activation='relu'))

# Layer 12: Convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
#model.add(layers.Conv2D(956, (3, 3), activation='relu'))


# Flatten the output for the fully connected layers
model.add(layers.Flatten())


# Layer 5: Output layer with 10 neurons (for 10 classes in MNIST) and softmax activation
model.add(layers.Dense(10, activation='softmax'))

# Train the model
#model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_data=(test_images, test_labels))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 30, 30, 48)        1344
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 128)       55424
#
#  conv2d_29 (Conv2D)          (None, 26, 26, 88)        101464
#
#  conv2d_30 (Conv2D)          (None, 24, 24, 68)        53924
#
#  conv2d_31 (Conv2D)          (None, 22, 22, 182)       111566
#
#  conv2d_32 (Conv2D)          (None, 20, 20, 80)        131120
#
#  conv2d_33 (Conv2D)          (None, 18, 18, 112)       80752
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 40)        40360
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 256)       92416
#
#  flatten_3 (Flatten)         (None, 50176)             0
#
#  dense_3 (Dense)             (None, 10)                501770
#
# =================================================================
# Total params: 1170140 (4.46 MB)
# Trainable params: 1170140 (4.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# number of classes
K = len(set(y_train))
print("number of classes:", K)

# input layer
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), activation='relu')(i)
# x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu')(x)
# x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu')(x)
# x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
# x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu')(x)
# x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
# x = BatchNormalization()(x)

x = Flatten()(x)
x = Dropout(0.2)(x)

# Hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

# output layer
x = Dense(K, activation='softmax')(x)

model = Model(i, x)
model.summary()

# %%
model.compile(optimizer='adam',
			loss='sparse_categorical_crossentropy',
			metrics=['accuracy'])

# %% [markdown]
# Training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size

r = model.fit(train_generator, validation_data=(x_test, y_test),
			steps_per_epoch=steps_per_epoch, epochs=2,callbacks=[EarlyStopping(monitor="val_accuracy",patience=7,verbose=1)])
# Out:
# Epoch 1/2
# 1562/1562 [==============================] - 48s 29ms/step - loss: 2.3033 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/2
# 1562/1562 [==============================] - 42s 27ms/step - loss: 2.3028 - accuracy: 0.0984 - val_loss: 2.3027 - val_accuracy: 0.1000

# %% [markdown]
# Prediction

# %%
test_loss, test_accuracy = model.evaluate(x_test,y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 2.3027 - accuracy: 0.1000
# Test Accuracy: 10.00%

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
for layer in model.layers:
  print(layer.get_weights())
# Out:
# [array([[[[-0.01497647,  0.00156985, -0.02543102, ..., -0.08136932,
#           -0.09671702, -0.10609666],
#          [ 0.10817506, -0.01450699,  0.06578304, ...,  0.09241538,
#           -0.06994621,  0.03123331],
#          [-0.09030981,  0.05376093, -0.10921655, ..., -0.05571442,
#           -0.00330664,  0.01641429]],
#
#         [[-0.05432792,  0.10451597,  0.04491942, ...,  0.06994284,
#           -0.05382083,  0.05170792],
#          [-0.0868895 , -0.07449538, -0.10698392, ..., -0.09060387,
#           -0.03909411,  0.00365509],
#          [ 0.052921  ,  0.05399739,  0.10095849, ..., -0.07880116,
#            0.06887208, -0.02664566]],
#
#         [[-0.10081243,  0.01814299, -0.01423934, ..., -0.04174611,
#           -0.10974848,  0.09429973],
#          [-0.03754104, -0.00092465,  0.00167458, ..., -0.08333872,
#            0.03176806,  0.01780816],
#          [ 0.01886413, -0.01957611, -0.11286582, ..., -0.07874836,
#           -0.07566234, -0.04064838]]],
#
#
#        [[[-0.0032315 , -0.08498587, -0.10207681, ...,  0.0274743 ,
#           -0.03351367, -0.0141472 ],
#          [ 0.07662729,  0.06477065, -0.06328524, ...,  0.07366376,
#           -0.02210136, -0.01621957],
#          [ 0.05610026, -0.02815846, -0.0656524 , ..., -0.05674496,
#           -0.1089756 ,  0.07067054]],
#
#         [[ 0.06364556,  0.09831711, -0.04661536, ..., -0.09746708,
#            0.10031861, -0.07128236],
#          [ 0.04120262,  0.02342306,  0.09991232, ...,  0.05249278,
#           -0.04995906,  0.02564561],
#          [ 0.01143011, -0.01263343, -0.03250724, ...,  0.05940865,
#            0.02137601, -0.05063676]],
#
#         [[-0.00090212,  0.08319436,  0.0807815 , ..., -0.0327058 ,
#           -0.09387953,  0.03938431],
#          [ 0.05458234,  0.06353824,  0.02293835, ..., -0.02292334,
#           -0.08145107, -0.06983774],
#          [-0.04088902, -0.0067241 ,  0.05730002, ..., -0.11494371,
#           -0.07618739, -0.05840823]]],
#
#
#        [[[ 0.09411262,  0.0281271 , -0.11313351, ...,  0.10585573,
#           -0.0850431 , -0.08624119],
#          [-0.09933036, -0.09568561,  0.08885859, ...,  0.10368142,
#            0.05855172,  0.09248441],
#          [-0.07844853, -0.08138666, -0.0835545 , ...,  0.05286941,
#            0.01802019, -0.03163555]],
#
#         [[-0.11179621, -0.08022695,  0.1024062 , ...,  0.09895731,
#            0.00064144,  0.05365303],
#          [ 0.0783581 ,  0.01352709, -0.11711568, ..., -0.00844025,
#           -0.04374623,  0.05741666],
#          [ 0.0858736 , -0.01201603,  0.03178211, ..., -0.03807467,
#           -0.07594529, -0.00336787]],
#
#         [[ 0.0759457 ,  0.09564015,  0.09810889, ...,  0.05744999,
#           -0.10449007, -0.01096635],
#          [ 0.08666407, -0.05082504, -0.081694  , ..., -0.070301  ,
#            0.10809277, -0.00469322],
#          [ 0.0719755 , -0.05650054,  0.10491589, ...,  0.02305412,
#            0.01516528, -0.04595415]]]], dtype=float32), array([-4.6979450e-03, -4.7187465e-03, -4.7006058e-03,  3.8396320e-03,
#        -7.1862452e-03, -4.8596412e-03, -4.6313778e-03, -5.0184005e-03,
#        -4.7315666e-03, -6.7289681e-03, -4.0995032e-03,  1.5716259e-03,
#        -4.9846978e-03,  5.7039759e-03, -5.7756454e-03, -4.5627868e-03,
#        -3.1849339e-03,  1.6662151e-03, -5.7121776e-03,  5.4179551e-03,
#        -6.6491542e-03, -3.9998223e-03, -3.6569522e-03, -7.5935475e-03,
#        -4.8514828e-03, -4.6627140e-03, -7.2436733e-03,  4.0252465e-03,
#        -6.5220040e-03,  5.7906969e-03, -6.6242348e-03,  8.9747063e-04,
#        -4.4939253e-03, -5.6298492e-03, -3.7303115e-03,  1.0732337e-03,
#        -4.7982782e-03,  1.1929891e-02, -4.5844926e-03, -5.2343551e-03,
#        -6.7053210e-05, -4.8992545e-03, -4.9029822e-03, -4.5316769e-03,
#        -7.2468622e-03, -6.1225174e-03, -1.4186769e-03, -4.6110279e-03],
#       dtype=float32)]
# [array([[[[-0.01257989,  0.04698686,  0.02909805, ..., -0.06093464,
#           -0.04147886,  0.05805104],
#          [ 0.0506513 , -0.03717329, -0.02039771, ..., -0.02506814,
#           -0.03819964, -0.03660903],
#          [ 0.0103456 , -0.05481033,  0.00258955, ..., -0.01389393,
#           -0.01903161,  0.00598085],
#          ...,
#          [-0.00728784, -0.05797012, -0.03046783, ...,  0.03212397,
#            0.03050738,  0.0564438 ],
#          [-0.00372433,  0.02409504, -0.00984892, ...,  0.0411002 ,
#           -0.05051633, -0.03306768],
#          [-0.03898829,  0.01555122,  0.01933165, ..., -0.06698109,
#            0.05038219, -0.02137249]],
#
#         [[ 0.02208849,  0.02231201, -0.06342614, ...,  0.00915427,
#           -0.04584192, -0.05425914],
#          [-0.02613959,  0.04016883, -0.06145699, ...,  0.04645623,
#            0.00991589,  0.02028432],
#          [-0.04196934,  0.01495102,  0.04558367, ..., -0.04889677,
#           -0.03417285,  0.02239203],
#          ...,
#          [ 0.03368668,  0.00828403, -0.05117964, ..., -0.02371575,
#           -0.02746897, -0.0262207 ],
#          [ 0.04737395,  0.04343932,  0.04760534, ...,  0.00531704,
#            0.05465624,  0.00211238],
#          [ 0.02899471,  0.05563201,  0.04261832, ..., -0.03548575,
#           -0.05262964,  0.00628798]],
#
#         [[-0.01334049,  0.01400476, -0.00813714, ..., -0.01656158,
#            0.04406185, -0.01096067],
#          [ 0.03917028,  0.03850766, -0.03640082, ...,  0.00606964,
#           -0.01153051,  0.00315698],
#          [-0.01677406,  0.00336469, -0.05755545, ...,  0.05399993,
#            0.02936585, -0.03687012],
#          ...,
#          [-0.01898445, -0.01047505,  0.01893381, ...,  0.04967578,
#            0.03679062,  0.04981225],
#          [-0.03793909, -0.04050716,  0.04098545, ..., -0.007383  ,
#           -0.05491237,  0.05148874],
#          [-0.04373688, -0.03541115,  0.04832395, ..., -0.0061554 ,
#            0.01199676,  0.00236795]]],
#
#
#        [[[-0.06319761, -0.00347026, -0.00876515, ..., -0.03001883,
#            0.0317826 ,  0.05119542],
#          [-0.02900835, -0.00254866,  0.00769283, ..., -0.02038846,
#           -0.05468555,  0.00783943],
#          [-0.02470468,  0.04125817,  0.0081276 , ..., -0.02357829,
#           -0.03338976,  0.0434187 ],
#          ...,
#          [-0.00136765, -0.00574349,  0.04525553, ...,  0.00344309,
#           -0.05216265, -0.04923701],
#          [ 0.05727005,  0.00582814, -0.00018971, ..., -0.01197279,
#           -0.05062344, -0.01054778],
#          [ 0.01790885,  0.03669967,  0.02912983, ...,  0.00627019,
#            0.03087166, -0.03296437]],
#
#         [[-0.05257089,  0.05345384,  0.03567507, ..., -0.06542121,
#           -0.0246201 ,  0.0276249 ],
#          [ 0.00265283,  0.02013703, -0.04067056, ..., -0.03936333,
#            0.01008435,  0.04842546],
#          [-0.0442486 ,  0.05756524,  0.00913997, ...,  0.02242795,
#            0.00674277, -0.0222842 ],
#          ...,
#          [-0.00070233, -0.04648656,  0.04368771, ...,  0.03519687,
#            0.0076501 , -0.0418671 ],
#          [ 0.05264834,  0.03840756,  0.05510268, ..., -0.04241855,
#            0.02044271,  0.0431854 ],
#          [ 0.03364882, -0.00469248, -0.02656732, ...,  0.03001227,
#           -0.02933995, -0.03537982]],
#
#         [[-0.04965924, -0.05971859,  0.01676351, ..., -0.02242506,
#            0.05203487, -0.00133013],
#          [ 0.05456999,  0.04842682, -0.05843376, ...,  0.01892646,
#           -0.02919931,  0.03777581],
#          [-0.00173336,  0.00158235,  0.01301253, ...,  0.01863133,
#           -0.05063408, -0.04103241],
#          ...,
#          [-0.00461762, -0.01039784,  0.02058379, ..., -0.04027853,
#            0.0299433 ,  0.03358935],
#          [-0.0544529 , -0.01647767, -0.00430096, ...,  0.01884819,
#            0.02822079, -0.01197538],
#          [ 0.04788962,  0.05495838, -0.00973671, ..., -0.04792933,
#           -0.0263775 , -0.0396181 ]]],
#
#
#        [[[ 0.01006149,  0.05987227,  0.03513351, ..., -0.04000202,
#           -0.03308644, -0.05059724],
#          [ 0.02848737,  0.00343097, -0.01703992, ..., -0.03052978,
#            0.02079276,  0.0587957 ],
#          [ 0.02718343,  0.04023178, -0.04733466, ..., -0.00687512,
#           -0.02744688, -0.05356228],
#          ...,
#          [-0.01057457, -0.03207912, -0.03130461, ..., -0.0371231 ,
#           -0.01141838,  0.05916363],
#          [-0.0455794 ,  0.03989267, -0.00534931, ...,  0.04098569,
#            0.03573839,  0.05292482],
#          [-0.00303182,  0.04353723, -0.03938884, ..., -0.0516618 ,
#           -0.02868076, -0.02418036]],
#
#         [[-0.0312628 ,  0.02864743,  0.03974538, ..., -0.03278532,
#           -0.04111999,  0.02786379],
#          [ 0.04853436,  0.00766282, -0.02168145, ...,  0.00435372,
#           -0.01329395,  0.05272799],
#          [-0.05599239, -0.03908214, -0.00257269, ..., -0.01385669,
#            0.02038074,  0.0465765 ],
#          ...,
#          [ 0.01477318, -0.00585234,  0.01231089, ..., -0.06581267,
#            0.03264273,  0.01547884],
#          [-0.02989867, -0.0108687 ,  0.03860959, ...,  0.02959391,
#           -0.02065218,  0.00431199],
#          [-0.00582925, -0.05721601, -0.06040328, ...,  0.00161089,
#           -0.00232405,  0.04917547]],
#
#         [[ 0.01901587, -0.01986246, -0.05572966, ...,  0.01134053,
#           -0.06269939,  0.01249681],
#          [ 0.01663513, -0.04254805, -0.03658525, ..., -0.02227847,
#            0.01768487, -0.01838072],
#          [ 0.02344134, -0.05048885,  0.04258427, ...,  0.01669522,
#           -0.03662126,  0.03771699],
#          ...,
#          [-0.03886295,  0.03215048,  0.04912218, ...,  0.03151201,
#            0.01647257, -0.0380374 ],
#          [ 0.01263319, -0.01068377, -0.05488994, ...,  0.02113815,
#            0.04672859,  0.05041287],
#          [-0.01460361,  0.0600985 ,  0.05435118, ..., -0.02984894,
#           -0.06105358,  0.06167834]]]], dtype=float32), array([-5.0864844e-03,  5.2405102e-04, -4.5105158e-03, -2.6334098e-03,
#            0.03098279,  0.04225343],
#          [-0.01868774, -0.0477634 , -0.02075844, ..., -0.01696067,
#           -0.04431105, -0.0489253 ],
#          [ 0.03433662, -0.02861904, -0.04025465, ..., -0.02171542,
#            0.00676216,  0.02072953]],
#
#         [[ 0.05888987, -0.02480731, -0.05791803, ..., -0.01664346,
#           -0.03609124,  0.00055254],
#          [ 0.02756227,  0.02545997, -0.02490572, ...,  0.03871501,
#            0.04431563,  0.03058825],
#          [-0.00691746, -0.01292145,  0.04651578, ..., -0.04209782,
#            0.0223699 ,  0.02724702],
#          ...,
#          [ 0.03562232,  0.02512557, -0.01715053, ..., -0.0500176 ,
#            0.01166304,  0.01052822],
#          [ 0.001941  ,  0.02746185,  0.01434902, ..., -0.02836351,
#           -0.02098488,  0.01104897],
#          [-0.02408965, -0.02926094,  0.02029543, ...,  0.00582353,
#           -0.01337531, -0.04092367]],
#
#         [[-0.04558121,  0.05339428, -0.02971708, ..., -0.01403092,
#            0.02642558,  0.01395499],
#          [ 0.01448174,  0.00913613, -0.00555749, ..., -0.04503896,
#            0.02314325,  0.04958741],
#          [ 0.00176722,  0.04426723, -0.0501097 , ...,  0.02731911,
#           -0.00143216,  0.02798564],
#          ...,
#          [-0.03235332,  0.03126867,  0.00333697, ..., -0.04041839,
#           -0.00929956, -0.02665916],
#          [ 0.04515241,  0.0527878 ,  0.02122716, ...,  0.0495433 ,
#            0.02370199, -0.0499725 ],
#          [ 0.04623938,  0.03634741,  0.00871393, ..., -0.03414003,
#           -0.02533509, -0.0432656 ]]],
#
#
#        [[[-0.04854391,  0.04320865, -0.00449817, ..., -0.01382525,
#            0.02271185,  0.00176681],
#          [-0.01268629,  0.02100257,  0.02212289, ...,  0.00167689,
#           -0.05940579,  0.01810755],
#          [ 0.02144625, -0.0413362 ,  0.0446228 , ..., -0.01245504,
#            0.03837042,  0.01646617],
#          ...,
#          [-0.00848467, -0.02593022, -0.0001347 , ..., -0.03759488,
#            0.02853029,  0.01580168],
#          [-0.02417798,  0.0484939 ,  0.04555634, ...,  0.00560654,
#            0.01727263, -0.05994045],
#          [-0.04782787, -0.0316891 ,  0.02700404, ...,  0.01924775,
#            0.01031323,  0.04557456]],
#
#         [[ 0.04231726, -0.01763288,  0.00429413, ..., -0.04325441,
#           -0.00156694,  0.03223488],
#          [ 0.02441633,  0.01417359,  0.03548381, ...,  0.03885236,
#           -0.04044346,  0.01465679],
#          [ 0.01227334, -0.0134497 ,  0.04922571, ...,  0.02732954,
#           -0.03523996, -0.01554874],
#          ...,
#          [ 0.01533818,  0.05521998,  0.01543254, ..., -0.00876116,
#           -0.00784398, -0.01067163],
#          [ 0.03544217,  0.04992059,  0.04063487, ..., -0.03939465,
#           -0.00269982, -0.00024032],
#          [-0.04672499,  0.0480411 , -0.04164774, ...,  0.01634923,
#            0.03061676, -0.00111521]],
#
#         [[-0.0035534 ,  0.0127837 ,  0.03292523, ...,  0.02250583,
#            0.00057704, -0.02403088],
#            0.02727089,  0.03992943],
#          ...,
#          [-0.05086566,  0.06404351, -0.0636704 , ...,  0.02163598,
#            0.04939246,  0.04246745],
#          [-0.03158762, -0.03736846,  0.05778792, ...,  0.03737386,
#            0.02993003, -0.0288464 ],
#          [ 0.03723881,  0.04150474,  0.00894348, ..., -0.0510243 ,
#           -0.03118512,  0.02398646]],
#
#         [[ 0.05646932,  0.00543974,  0.05379873, ..., -0.05864382,
#           -0.00672494, -0.05636393],
#          [ 0.0092247 ,  0.04139384, -0.01539331, ..., -0.03327523,
#           -0.02004112,  0.03327468],
#          [-0.00887445, -0.04398788, -0.0612395 , ...,  0.04742584,
#            0.0493515 , -0.03470476],
#          ...,
#          [-0.00600225,  0.04180568,  0.02178109, ..., -0.03441285,
#           -0.02386031, -0.01799868],
#          [ 0.04181993,  0.0471715 ,  0.00636028, ...,  0.01678295,
#           -0.06563808, -0.00471008],
#          [ 0.03599885, -0.04737164,  0.00852704, ...,  0.05673505,
#            0.03257251,  0.02874007]],
#
#         [[-0.05436439, -0.01545139, -0.03098661, ..., -0.05232676,
#            0.05020503, -0.0569303 ],
#          [ 0.00670564, -0.056096  ,  0.05214083, ...,  0.04393041,
#           -0.05239544,  0.00610947],
#          [ 0.04327046,  0.01003547, -0.04312781, ..., -0.06404722,
#            0.00880967,  0.0542847 ],
#          ...,
#          [-0.02258793,  0.04658176,  0.04860935, ...,  0.02869455,
#            0.0497565 ,  0.04417995],
#          [ 0.05220626, -0.00050147, -0.04782102, ..., -0.05138623,
#           -0.04889405, -0.04132853],
#          [ 0.05360136, -0.05900108, -0.00664933, ..., -0.06957381,
#           -0.01757045, -0.00958959]]],
#
#
#        [[[ 0.00329499, -0.04015531, -0.00243405, ..., -0.02063179,
#            0.0210602 ,  0.01755067],
#          [ 0.05943808,  0.02944522, -0.0296896 , ..., -0.00999541,
#           -0.06276492,  0.04420888],
#          [-0.06376103, -0.06200842,  0.00600386, ...,  0.02411148,
#           -0.05792664, -0.0169438 ],
#          ...,
#          [-0.05143683, -0.06105462,  0.01898249, ...,  0.00311552,
#           -0.06756542,  0.05966236],
#          [ 0.01152174, -0.01891164,  0.01646787, ..., -0.05861416,
#            0.02794988,  0.05234678],
#          [-0.01999353, -0.04712073,  0.02233546, ...,  0.01845925,
#            0.02962761,  0.0351687 ]],
#
#         [[-0.00286453, -0.05626264,  0.05474092, ...,  0.02731051,
#           -0.01205468,  0.04358057],
#          [ 0.02302335,  0.03471985, -0.01831774, ..., -0.06903962,
#            0.01835895, -0.06289539],
#          [ 0.01610318, -0.03607086, -0.03514422, ...,  0.03892259,
#           -0.05015226, -0.00229204],
#          ...,
#          [ 0.0587999 , -0.03142683, -0.06272608, ..., -0.04512496,
#           -0.0430217 , -0.02015604],
#          [-0.03777911, -0.02134852,  0.06085119, ..., -0.01315903,
#           -0.01716532, -0.00553695],
#          [ 0.04247423,  0.050247  , -0.04446333, ..., -0.04780468,
#           -0.02435954,  0.0218461 ]],
#
#         [[ 0.01698197, -0.0391686 , -0.01437457, ...,  0.01457945,
#           -0.00969451,  0.02577861],
#          [ 0.01327136, -0.00633513,  0.02602802, ..., -0.01991001,
#           -0.03603886, -0.02299091],
#          [ 0.01642156,  0.04697368,  0.01445596, ...,  0.05131835,
#            0.01803911,  0.01185225],
#          ...,
#          [ 0.03024359,  0.04017862, -0.00765081, ..., -0.04921928,
#           -0.05608095, -0.032845  ],
#          [-0.02232354,  0.03387847,  0.03981672, ...,  0.02684664,
#           -0.01190834,  0.05330041],
#          [-0.02513354,  0.03277483,  0.04877766, ...,  0.01428866,
#            0.03131332, -0.04779836]]],
#
#
#        [[[-0.03499228, -0.00728291,  0.04612303, ..., -0.0253012 ,
#            0.00626522, -0.04127968],
#          [ 0.02639862, -0.01702101,  0.0306961 , ...,  0.02568617,
#            0.02217038,  0.0393679 ],
#          [ 0.03680827,  0.01497529, -0.02253692, ...,  0.03235176,
#            0.0298338 ,  0.0447239 ],
#          ...,
#          [ 0.03900805,  0.00029602,  0.03884391, ..., -0.04254702,
#            0.02383853,  0.04031415],
#          [-0.00466673,  0.02039494, -0.03683856, ..., -0.02300553,
#           -0.03033357,  0.04908301],
#          [ 0.02088026, -0.0258264 , -0.02612833, ...,  0.02356071,
#           -0.05332042, -0.05656835]],
#
#         [[-0.04228109, -0.03352076, -0.03379921, ..., -0.02746892,
#            0.03341077, -0.03170058],
#          [-0.04384163, -0.02493887,  0.03049265, ..., -0.04907595,
#           -0.00729355, -0.02372429],
#          [-0.00519339,  0.04086041,  0.00959507, ..., -0.04892065,
#           -0.00211343,  0.03665047],
#          ...,
#          [ 0.02506774, -0.02752429, -0.03976282, ...,  0.03076779,
#            0.01654999,  0.02897968],
#          [-0.00992792,  0.02613694,  0.03013957, ...,  0.04734296,
#            0.01973827,  0.01341935],
#          [-0.0008392 ,  0.02416226, -0.04799768, ...,  0.01121688,
#           -0.05522144, -0.0095381 ]],
#
#         [[ 0.02934156, -0.00304522, -0.02604579, ...,  0.03565624,
#            0.038895  , -0.0063752 ],
#          [-0.04103519,  0.01487091,  0.01124379, ..., -0.00770934,
#           -0.05024575, -0.03398088],
#          [-0.00539489, -0.04387368,  0.03232   , ...,  0.00663509,
#            0.04790661, -0.04212553],
#          ...,
#          [ 0.02973584,  0.01503641,  0.00624609, ...,  0.02283895,
#           -0.04219412,  0.01614024],
#          [ 0.03404017, -0.01000439,  0.03314268, ..., -0.02926063,
#            0.00023883, -0.00865024],
#          [-0.03259078, -0.01971187, -0.03455824, ..., -0.01995443,
#           -0.01104965,  0.03517438]]],
#
#
#        [[[ 0.03920155, -0.02806343,  0.0021214 , ...,  0.04643833,
#            0.02559254, -0.029029  ],
#          [ 0.03893821, -0.04668777,  0.04700937, ..., -0.03189678,
#            0.00129276,  0.00279806],
#          [ 0.03111877, -0.04124513, -0.05145102, ...,  0.01723978,
#           -0.02178704, -0.00380339],
#          ...,
#          [-0.03808209,  0.03873603,  0.04199881, ...,  0.01150706,
#           -0.00138418, -0.02978699],
#          [-0.03000699,  0.03103658, -0.0273536 , ...,  0.00243954,
#            0.01231529,  0.02439031],
#          [ 0.02618724,  0.01071597,  0.02624081, ...,  0.02185094,
#           -0.00736993, -0.04561115]]],
#
#
#        [[[-0.04057366, -0.03742865, -0.03304928, ..., -0.01522028,
#           -0.0351636 , -0.027425  ],
#          [ 0.01625668,  0.00827414, -0.01780559, ..., -0.02263501,
#           -0.0226062 ,  0.01945729],
#          [ 0.00561695,  0.00350849,  0.01061437, ...,  0.02514327,
#            0.02770586,  0.03969991],
#          ...,
#          [ 0.01692977,  0.02877327, -0.02221547, ...,  0.00349871,
#           -0.02692953,  0.03684916],
#          [-0.04522054,  0.00846608,  0.04382839, ..., -0.01749043,
#            0.04598181, -0.00190613],
#          [-0.02192441,  0.04413142, -0.00999273, ..., -0.0316104 ,
#           -0.01721814,  0.02524929]],
#
#         [[-0.04679329, -0.04615553,  0.03101322, ...,  0.03562619,
#            0.02861876, -0.03747902],
#          [ 0.00308253, -0.00568962, -0.00039077, ..., -0.01847257,
#           -0.03957655,  0.04955602],
#          [-0.01730247, -0.00871891,  0.0136866 , ...,  0.05032455,
#            0.03533471,  0.0320913 ],
#          ...,
#          [ 0.05103022,  0.00174716, -0.001868  , ..., -0.0018635 ,
#            0.05530223,  0.03887854],
#          [-0.01518947,  0.0393527 , -0.02148027, ..., -0.0401526 ,
#            0.00855969, -0.0063383 ],
#          [ 0.03075613,  0.0216242 , -0.01478223, ...,  0.04243845,
#            0.05362297,  0.02462903]],
#
#         [[-0.04369813, -0.0120494 , -0.00083842, ...,  0.02780589,
#            0.0174492 ,  0.00306564],
#          [ 0.01391253,  0.03594461, -0.00734608, ..., -0.02847601,
#           -0.00954658,  0.03264798],
#          [-0.01442569,  0.01186553,  0.01370875, ...,  0.00919757,
#            0.04879146,  0.02170996],
#          ...,
#          [ 0.04928283,  0.0341622 ,  0.05400851, ...,  0.03244042,
#            0.02190926, -0.02265192],
#          [ 0.047856  ,  0.01398585, -0.01309024, ...,  0.0093129 ,
#           -0.03135062,  0.00483351],
#          [ 0.0171036 ,  0.04440035,  0.05431302, ...,  0.03589455,
#           -0.01768913,  0.00615866]]],
#
#
#        [[[ 0.01927993, -0.01162352, -0.02126008, ..., -0.01861043,
#           -0.03327921,  0.02100493],
#          [ 0.04941009, -0.04576442,  0.02467318, ...,  0.01262376,
#           -0.01759581,  0.0349206 ],
#          [ 0.0196033 , -0.03743733, -0.01955295, ...,  0.0097563 ,
#            0.02805611,  0.04541384],
#          ...,
#          [ 0.02677543, -0.0463676 ,  0.03678329, ..., -0.02670447,
#            0.01870303, -0.01779085],
#          [-0.00950218,  0.00533   , -0.02653505, ...,  0.02900529,
#            0.01616882, -0.04363568],
#          [ 0.01138902,  0.03082992,  0.0046757 , ...,  0.03115658,
#           -0.03311266, -0.0209036 ]],
#
#         [[ 0.03136652,  0.01922661, -0.01275523, ..., -0.05753366,
#            0.02058323, -0.02946787],
#          [-0.0094649 , -0.01329871, -0.01568262, ...,  0.04219792,
#           -0.04365241, -0.0162274 ]],
#
#         [[-0.00282566,  0.00624731,  0.03250879, ..., -0.02200377,
#           -0.03444863,  0.02350075],
#          [ 0.01598021,  0.02059677, -0.04714344, ..., -0.03082573,
#            0.04422074, -0.01645819],
#          [ 0.029589  ,  0.04384356, -0.02038115, ...,  0.05398931,
#           -0.05539573, -0.05935369],
#          ...,
#          [-0.02571234,  0.04398185, -0.01987818, ..., -0.063007  ,
#            0.0241771 , -0.04870258],
#          [ 0.03387511,  0.00874819,  0.02490781, ..., -0.0227375 ,
#           -0.03056889,  0.00221894],
#          [ 0.00129579,  0.00393616,  0.01908189, ...,  0.04260815,
#            0.05493821,  0.00373141]],
#
#         [[-0.048343  ,  0.04230472,  0.03275663, ...,  0.00401192,
#           -0.05081351, -0.04537332],
#          [-0.02478812,  0.01563037, -0.05176735, ...,  0.02370116,
#            0.04564061,  0.02096697],
#          [ 0.04272439,  0.02908665,  0.02533483, ...,  0.03268063,
#            0.00857438, -0.0623662 ],
#          ...,
#          [ 0.00799821,  0.0346355 , -0.04855218, ...,  0.02184464,
#           -0.01977188, -0.0405139 ],
#          [ 0.02050776,  0.04833989, -0.03785527, ...,  0.02710625,
#           -0.06319225,  0.01541977],
#          [ 0.05107188, -0.01904088,  0.02364526, ...,  0.00761991,
#           -0.0261405 , -0.04516893]]],
#
#
#        [[[ 0.04646529, -0.00626031, -0.0058681 , ..., -0.0083796 ,
#            0.02902506,  0.0482934 ],
#          [-0.01965657, -0.02540235,  0.03560115, ...,  0.01235017,
#            0.057201  , -0.03991273],
#          [-0.00687851, -0.06065138, -0.01493928, ..., -0.01767972,
#           -0.00044804,  0.05332823],
#          ...,
#          [-0.00668908,  0.03423335, -0.03563762, ..., -0.05411914,
#            0.0157438 ,  0.00500306],
#          [-0.0432728 ,  0.01003683, -0.00928265, ...,  0.01384467,
#           -0.00892833,  0.00102197],
#          [ 0.0332143 , -0.04780804,  0.02600281, ..., -0.02431133,
#            0.02886737, -0.04935309]],
#
#         [[-0.03216201, -0.02893908,  0.05209186, ..., -0.05192932,
#           -0.01969678, -0.02611411],
#          [-0.03977691, -0.04637051,  0.0350357 , ...,  0.00793084,
#           -0.02601635, -0.05074307],
#          [-0.00542694,  0.04220014, -0.02281874, ..., -0.02584531,
#            0.01280296,  0.0150672 ],
#          ...,
#          [-0.02597818, -0.00657119, -0.0120946 , ..., -0.03320264,
#            0.01496523, -0.04002949],
#          [ 0.02548077,  0.04939976,  0.01206269, ..., -0.04646352,
#           -0.02785048, -0.01812739],
#          [-0.00631326,  0.03600477,  0.00392879, ...,  0.0280409 ,
#            0.02531144,  0.00112738]],
#
#         [[ 0.01973725,  0.03641985, -0.00713238, ..., -0.02802696,
#           -0.00904994,  0.00372753],
#          [ 0.02296592,  0.00186759,  0.04385886, ..., -0.0033257 ,
#           -0.02361091,  0.04949584],
#          [ 0.02862629,  0.01994835,  0.03174881, ...,  0.04943569,
#           -0.0533361 , -0.00876355],
#          ...,
#          [-0.06234127,  0.03709494, -0.00017879, ..., -0.01767393,
#           -0.0073274 ,  0.03993196],
#          [-0.01383038,  0.0409537 , -0.00438821, ..., -0.02125134,
#           -0.0522683 ,  0.00378901],
#          [ 0.01075795,  0.0241094 , -0.01386696, ...,  0.01560871,
#            0.03030242, -0.02275269]]],
#
#
#        [[[-0.05785599, -0.00511356,  0.00205916, ...,  0.01593584,
#            0.02748881, -0.05596209],
#          [ 0.00828059, -0.04029601, -0.01782257, ..., -0.00532513,
#            0.04296933, -0.05676834],
#          [-0.02321899,  0.01735094, -0.04721233, ..., -0.01490893,
#           -0.0040086 , -0.05021416],
#          ...,
#          [-0.01181033,  0.04689739, -0.00994008, ..., -0.00823434,
#           -0.05348572, -0.04721398],
#          [ 0.03900413,  0.03276276,  0.03429215, ..., -0.00505513,
#            0.05268608,  0.04196613],
#          [ 0.04024035, -0.03207293,  0.02195876, ..., -0.05060514,
#           -0.0371509 , -0.00981027]],
#
#         [[ 0.04268485, -0.04593561, -0.00297691, ...,  0.02090202,
#            0.01482629,  0.00225464],
#          [ 0.01001098,  0.0005315 ,  0.03943364, ..., -0.0501287 ,
#           -0.0269472 ,  0.01836235],
#          [-0.04465656,  0.01398013,  0.04885346, ..., -0.06164945,
#            0.0220182 ,  0.02931176],
#          ...,
#          [-0.04778147,  0.01748481, -0.01141296, ...,  0.02268547,
#           -0.00352226,  0.00860272],
#          [-0.05312477,  0.04372906,  0.02029072, ..., -0.04577717,
#           -0.05060636,  0.00498593],
#          [-0.01099357,  0.017006  , -0.05351599, ..., -0.02895799,
#            0.05379307, -0.05566629]],
#
#         [[-0.03800193,  0.0109324 , -0.01364886, ...,  0.04621325,
#           -0.02485606,  0.0188151 ],
#          [ 0.02704108, -0.04534815,  0.03107953, ...,  0.02211439,
#            0.02988324,  0.03874522],
#          [ 0.02190028, -0.00531699,  0.03372958, ...,  0.0472592 ,
#            0.03915   , -0.02758   ],
#          ...,
#          [ 0.01217047, -0.01965695,  0.04395852, ..., -0.05981784,
#           -0.01193745, -0.00245545],
#          [ 0.01879416,  0.00354972,  0.02838217, ..., -0.04053445,
#           -0.06158912,  0.05620871],
#          [ 0.02119244, -0.04800475,  0.02909822, ...,  0.01072672,
#            0.01616628, -0.053592  ]]]], dtype=float32), array([-5.49699552e-03, -7.20623648e-03,  7.94610661e-03, -2.85971793e-03,
#        -4.32898384e-03, -1.90325559e-03,  5.53858746e-03, -2.88169109e-03,
#        -7.04724574e-03, -3.28982016e-03, -3.65390471e-04, -3.54511500e-03,
#        -8.37976206e-03, -4.53682803e-03, -4.55358019e-03, -8.12857877e-03,
#        -9.82993282e-03, -1.16218755e-03,  8.63734912e-03, -5.74396411e-03,
#         7.71646481e-03, -8.42173060e-04,  9.20435507e-03, -8.60329904e-03,
#        -4.54140827e-03,  2.09270953e-03, -5.11354115e-03, -4.38212138e-03,
#        -4.25155694e-03, -4.15612850e-03, -6.35700580e-03, -1.55095558e-03,
#        -2.13698694e-03, -4.34391107e-03, -7.71258352e-03,  0.00000000e+00,
#        -0.00598243, -0.00346046, -0.005622  , -0.00713306, -0.00356569,
#        -0.0035977 , -0.00432764, -0.00459531, -0.00658728, -0.0053387 ,
#        -0.005816  , -0.00310406, -0.00378808, -0.00709446, -0.0041612 ,
#        -0.00732427, -0.006033  , -0.00433148, -0.00282119, -0.00340528,
#        -0.00415376, -0.00809199, -0.00471917, -0.00181179, -0.00809184,
#        -0.00492251, -0.0044045 , -0.00739789, -0.00317661, -0.00643559,
#        -0.00465436, -0.00069805, -0.00887974, -0.00702267, -0.00437114,
#        -0.00253308, -0.00394753, -0.00604851, -0.00414899, -0.0097615 ,
#        -0.00387569, -0.00715396, -0.00490257, -0.00472593, -0.00723338,
#        -0.00591807, -0.00438456, -0.00149679, -0.00172886, -0.00724726,
#        -0.00691753, -0.00790428, -0.00388012, -0.0073221 , -0.00890952,
#        -0.00676433, -0.0041434 , -0.0057357 , -0.00499154, -0.00514468,
#        -0.00420647, -0.00691104, -0.00418641, -0.00728437, -0.00600281,
#        -0.00598475, -0.00652597, -0.0080071 , -0.00499682, -0.006544  ,
#        -0.00433038, -0.00888117, -0.00489906, -0.00382629, -0.00472883,
#        -0.00354443, -0.00383443, -0.00453832, -0.00610398, -0.00480644,
#        -0.00099075, -0.00554798, -0.00548267, -0.00765297, -0.00550672,
#        -0.00440291, -0.00329607, -0.00939939, -0.0051864 , -0.0069611 ,
#        -0.00629371, -0.00600486, -0.00637903, -0.00562639, -0.00085158,
#        -0.00591894, -0.00472988, -0.0007992 , -0.00752083, -0.00397681,
#        -0.00751183, -0.00428673, -0.01045886, -0.00686086, -0.0067298 ,
#        -0.00440659], dtype=float32)]
# []
# [array([[-2.1618551e-03,  5.6703039e-03, -3.4580319e-03, ...,
#          4.8812752e-04,  1.2498819e-03, -7.0713186e-03],
#        [-3.9144787e-03, -7.2593815e-03, -1.5463264e-03, ...,
#          5.0611761e-03,  4.4562225e-03, -1.2688535e-02],
#        [-4.8075593e-03,  7.5359815e-03, -7.0933611e-03, ...,
#         -9.6569508e-03, -4.8111011e-03,  6.1839684e-03],
#        ...,
#        [-2.8288207e-04, -5.0090617e-03,  1.1093519e-03, ...,
#         -1.3337172e-02, -9.0791229e-03,  1.4606426e-02],
#        [-5.9703697e-04,  1.0150994e-02, -2.7448330e-03, ...,
#         -6.5771135e-05, -1.5447787e-02, -3.9884541e-03],
#        [-4.5906799e-03,  9.7857341e-03, -4.1051018e-03, ...,
#         -3.4683771e-03, -7.1925316e-03,  5.2756849e-03]], dtype=float32), array([-0.02454633, -0.00683122, -0.00447313, -0.00142398,  0.00248097,
#        -0.00971826,  0.00451033,  0.01517458, -0.01387899,  0.02349482],
#       dtype=float32)]

# %%
b = 8
alpha_q = -2**(b-1)
beta_q = (2**(b-1) - 1)
print(alpha_q)
print(beta_q)
for layer in model.layers:
  #print(layer.name)
  if layer.name!='flatten_3':
    #print("yes")
    #print(layer.get_weights())
    (W,B) = np.array(layer.get_weights())
    #print("bias of", layer.name,B)
    alpha_W = np.min(W)
    beta_W = np.max(W)
    alpha_B = np.min(B)
    beta_B = np.max(B)
    s_W = (beta_W - alpha_W) / (beta_q - alpha_q)
    s_B = (beta_B - alpha_B) / (beta_q - alpha_q)
    z_W = np.round((beta_W*alpha_q - alpha_W*beta_q)/(beta_W - alpha_W))
    z_B = np.round((beta_B*alpha_q - alpha_B*beta_q)/(beta_W - alpha_W))
    #print(W)
    #print(B)
    W1 = np.round(( (W / s_W) + z_W), decimals=0)
    B1 = np.round(( (B / s_B) + z_B), decimals=0)
    #print(W1)
    #print(B1)
    W2 = np.clip(W1, alpha_q, beta_q)
    B2 = np.clip(B1, alpha_q, beta_q)
    #print(W2)
    #print(B2)
    W_quantized = W2.astype('int')
    B_quantized = B2.astype('int')
    #print(W_quantized)
    #print(B_quantized)
    Dist = [W_quantized, B_quantized]
    #print(Dist)
    layer = layer.set_weights(Dist)
# Out:
# -128
# 127
# <ipython-input-56-8167973f3b9d>:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   (W,B) = np.array(layer.get_weights())

# %%
(W,B) = np.array(model.layers[1].get_weights())
# Out:
# <ipython-input-71-f62bcb098c90>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   (W,B) = np.array(model.layers[1].get_weights())

# %%
W = W.flatten()
W
# Out:
# array([ -26.,   77.,   46., ...,  -55., -109.,  102.], dtype=float32)

# %%
B.flatten()
B
# Out:
# array([ -57.,    5.,  -50.,  -30.,  -82.,  -51.,  -50.,  -75.,  -48.,
#         -52.,    8.,  -66.,  -32.,  -98.,   33.,   16.,  -75.,   92.,
#         -52.,  -74.,  -52.,  -65.,  -51.,  -51.,   38.,  -88.,  -49.,
#          46.,  -50.,  -63.,  -60.,  -51.,   90.,  -65.,  -50.,  -84.,
#         -66.,  -51.,  -48.,   24.,  -72.,  -51.,   28.,  -59.,  -51.,
#          64.,  -81.,   42.,  -53.,  -64.,  -52.,  -51.,  -73.,  -82.,
#         -54.,   -4.,   67.,   47.,    9.,   94.,  -61.,  -43.,   16.,
#         -51.,  -30.,  -73.,  -20.,  -45.,  -51.,  -54.,  -50.,  -73.,
#          10.,   50.,  -76.,   68.,  -44.,  -75.,  -73.,  -17.,   34.,
#          -1.,  -73.,   42.,  -20.,  -51., -121.,   39.,  -51.,  -98.,
#         -52.,  -11.,  -94.,  -50.,  -54.,  -39.,  -71.,  -62., -106.,
#         -51.,   19.,  -95.,  -73.,  127.,  -69.,   98.,  -50.,   59.,
#          74.,  -50.,   89.,  -73.,  -51.,   62.,  -52.,  -52.,  -51.,
#         -53.,  -75.,  -88.,  -52.,  -67.,  -36.,  -21.,   -4.,  -74.,
#         -51.,   40.], dtype=float32)

# %%
with open('weight_data.txt', 'w') as file:
  for layer in model.layers:
    if layer.name!='flatten_3':
      file.write(f"Layer Name: {layer.name}\n")
      file.write(f"Layer Shape: {layer.output_shape}\n")
      (W,B) = np.array(layer.get_weights())
      file.write(f"Layer weights: {W.flatten()}\n")
      file.write(f"Layer bias: {B.flatten()}\n")
      file.write("\n")
# Out:
# <ipython-input-75-04bb9f5b1ee6>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   (W,B) = np.array(layer.get_weights())
